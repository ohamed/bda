# %% [markdown]
# <b>Description:</b>
# -

# %% [markdown]
# ### Import Python libraries and user-defined modules

# %%
#from dotenv import load_dotenv
import pandas as pd
import data_profiling
from data_profiling import ProfileReport

# %%
#import prep.preprocessing as prep

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
#import os
#os.getcwd()

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\o.hamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\o.hamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\o.hamed\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ### Load variables from .env file

# %%
#load_dotenv()

XLSX_FILES_FOLDER = "../data/xlsx"
HTML_REPORTS_FOLDER = "../reports"

XLSX_FILES_FOLDER, HTML_REPORTS_FOLDER
# Out:
# ('../data/xlsx', '../reports')

# %% [markdown]
# ### Read the dataset and high-level EDA

# %%
#df = read_excel_files(XLSX_FILES_FOLDER, pattern, debug=True)
df= pd.read_excel(XLSX_FILES_FOLDER+"/image_metadata.xlsx", sheet_name="Sheet1")

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

## Add more stopwords
stop_words.add("two")

def preprocess(text):

    text = text.lower()

    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    tokens = text.split()#I love Palestine

    tokens = [
        lemmatizer.lemmatize(w)
        for w in tokens
        if w not in stop_words and len(w) > 2
    ]

    return " ".join(tokens)

# %%
#df.shape ##(502, 9)
## This from pandas syntax, please watch the pandas review.
df["caption_clean"] = df["caption"].apply(preprocess)

# %%
df.head()
# Out:
#    project_id   category            image_id  \
# 0         212  Reflector     20180105_101214
# 1         212  Reflector     20180105_101224
# 2         212  Reflector     20180302_135657
# 3         212  Reflector     20180302_135706
# 4         212  Reflector  20180418-Vortest-1
#
#                                              caption  caption_ai  \
# 0  a large stainless steel disc with a milled sur...         NaN
# 1                          a rectangular steel plate         NaN
# 2  Housing of the beryllium reflector, clamped wi...         NaN
# 3  Housing of the beryllium reflector, clamped wi...         NaN
# 4  Mounted housing of the beryllium reflector on ...         NaN
#
#                                        caption_clean
# 0          large stainless steel disc milled surface
# 1                            rectangular steel plate
# 2  housing beryllium reflector clamped six black ...
# 3  housing beryllium reflector clamped six black ...
# 4  mounted housing beryllium reflector traversing...

# %%
col_to_drop = "caption_ai"
df_ic = None

if col_to_drop in df.columns:
    df_ic = df.drop(columns=[col_to_drop])
df_ic.head()
# Out:
#    project_id   category            image_id  \
# 0         212  Reflector     20180105_101214
# 1         212  Reflector     20180105_101224
# 2         212  Reflector     20180302_135657
# 3         212  Reflector     20180302_135706
# 4         212  Reflector  20180418-Vortest-1
#
#                                              caption  \
# 0  a large stainless steel disc with a milled sur...
# 1                          a rectangular steel plate
# 2  Housing of the beryllium reflector, clamped wi...
# 3  Housing of the beryllium reflector, clamped wi...
# 4  Mounted housing of the beryllium reflector on ...
#
#                                        caption_clean
# 0          large stainless steel disc milled surface
# 1                            rectangular steel plate
# 2  housing beryllium reflector clamped six black ...
# 3  housing beryllium reflector clamped six black ...
# 4  mounted housing beryllium reflector traversing...

# %%
#df_ic.info()

# %% [markdown]
# ### Generate Reports using YData/YData-SDK Profiling

# %%
import time

# %%
start = time.time()
title = "IC for Archive Projects-ITE"

#profile = ProfileReport(df_ic, title=f"{title}", minimal=False, correlations={"pearson": {"calculate": True}, "spearman": {"calculate": True}})
profile = ProfileReport(df_ic, title=f"{title}")

out_html = HTML_REPORTS_FOLDER + f"/{title}.html"
profile.to_file(out_html)

end = time.time()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 81.19it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
minutes = (end - start) / 60
print(f"Report generated in {minutes:.2f} minutes")
# Out:
# Report generated in 0.26 minutes
