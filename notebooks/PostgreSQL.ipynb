# %%
import psycopg2

# %%
## Database connection parameters
conn = psycopg2.connect(
    dbname="bda_db",
    user="postgres",
    password="pwd",
    host="localhost",  # Change to your server if needed
    port="5433"  # Default PostgreSQL port
)

# %%
## Create a cursor to execute queries
cur = conn.cursor()

# %%
## Execute a simple query
cur.execute("SELECT * from users_tbl")

# %%
cur.fetchall()
# Out:
# []

# %%
## Fetch and print the result
print(cur.fetchone())
# Out:
# (1, 'Alice Johnson', 'alice@example.com', 'hashed_password_1', datetime.datetime(2026, 5, 20, 16, 7, 42, 175742))

# %%
print(cur.fetchone())
# Out:
# (2, 'Bob Smith', 'bob@example.com', 'hashed_password_2', datetime.datetime(2026, 5, 20, 16, 7, 42, 175742))

# %%
print(cur.fetchone())
# Out:
# (3, 'Charlie Brown', 'charlie@example.com', 'hashed_password_3', datetime.datetime(2026, 5, 20, 16, 7, 42, 175742))

# %%
print(cur.fetchone())
# Out:
# None

# %%
print(cur.fetchone())
# Out:
# None
